# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns

# %%
df=pd.read_csv('salary_experience_dataset.csv')
df.head()
# Out:
#    YearsExperience        Salary
# 0                6  34518.324084
# 1               19  57940.060897
# 2               14  58344.706427
# 3               10  39380.508327
# 4                7  45250.026978

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['YearsExperience']],df['Salary'],test_size=0.3,random_state=17)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((70, 1), (30, 1), (70,), (30,))

# %%
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
acc=r2_score(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(f'R2 Score: {acc}, RMSE: {rmse}')
# Out:
# R2 Score: 0.7072065809624133, RMSE: 4579.822081499353

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel('Actual Salary')
plt.ylabel('Predicted Salary')
sns.lineplot(x=y_test, y=y_test, color='red')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='blue')
plt.show()

# %% [markdown]
# Below are the Samples between Scatter Plot and Lineplot in SNS

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2.3, 3.7, 4.1, 5.8, 6.2]

sns.scatterplot(x=x, y=y)
plt.title("Scatter Plot")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2.3, 3.7, 4.1, 5.8, 6.2]

sns.lineplot(x=x, y=y)
plt.title("Line Plot")
plt.show()
